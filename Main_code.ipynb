# %% [markdown]
# # Structure of the Data

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Connexion to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import home-made classes

# %%
# %cd /content/drive/MyDrive/ML\ BigProject

# File where classes are located
# %run library.py
# Out:
# /content/drive/MyDrive/ML BigProject

# %% [markdown]
# All classes and functions will finaly be in the PY file

# %% [markdown]
# # Data importation

# %% [markdown]
# # Descriptive statistics

# %% [markdown]
# # Machine learning models
